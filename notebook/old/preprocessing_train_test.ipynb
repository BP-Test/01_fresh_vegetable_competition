# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = "MS Gothic" # Use this font to avoid encoding error
import os
import json

import sys
sys.path.append('../src/')
sys.dont_write_bytecode = True  # __pycache__ 生成を防ぐ

from vege_preprocess import Preprocess, Weather

# %%
test = Preprocess()
test.preprocess_train_test()
test.get_weather_data()
test.add_weather_features()

# %%
target =pd.read_csv('../data/preprocessed_weather.csv')

# %%
test.wea_df
# Out:
#      year  month  mean_temp_mean  mean_temp_max  mean_temp_min  max_temp_mean  \
# 0    2004     11       14.596000      19.299999       9.600000      18.340000
# 1    2004     12        9.641935      19.000000       2.200000      13.564516
# 2    2005      1        6.277420      13.100000       3.100000      10.461290
# 3    2005      2        5.960714      12.000000       3.300000       9.864285
# 4    2005      3        8.800000      13.700000       1.600000      13.122581
# ..    ...    ...             ...            ...            ...            ...
# 205  2021     12        4.800470      11.138542      -1.777083       8.583669
# 206  2022      1        1.904604       4.685417      -1.246875       5.414617
# 207  2022      2        2.234263       7.326042      -1.204167       5.883334
# 208  2022      3        7.032897      12.596875       2.503125      11.725605
# 209  2022      4       12.550138      19.040625       5.991666      17.947603
#
#      max_temp_max  max_temp_min  min_temp_mean  min_temp_max  ...  \
# 0       22.200001     12.400000      11.228000     17.400000  ...
# 1       24.299999      3.800000       6.138710     11.500000  ...
# 2       17.200001      5.200000       2.522581      6.400000  ...
# 3       15.400000      5.100000       2.060714      4.600000  ...
# 4       18.400000      3.600000       4.596774     10.000000  ...
# ..            ...           ...            ...           ...  ...
# 205     16.021875      0.788542       1.293582      6.922916  ...
# 206      9.112500      1.068750      -1.184308      2.327083  ...
# 207     12.273959      1.079167      -1.035863      3.179167  ...
# 208     19.009375      5.089583       2.953259      7.818750  ...
# 209     25.631250      9.831250       7.406007     15.103126  ...
#
#      sum_rain_mean  sum_rain_max  sum_rain_min  sun_time_mean  sun_time_max  \
# 0         5.840000     87.000000           0.0       5.084000      9.500000
# 1         2.435484     26.000000           0.0       5.509677      9.400000
# 2         3.338710     66.500000           0.0       6.612903      9.800000
# 3         1.910714     11.500000           0.0       5.225000      9.700000
# 4         2.612903     22.500000           0.0       5.529032     11.300000
# ..             ...           ...           ...            ...           ...
# 205       3.748992     25.854166           0.0       3.618952      8.969791
# 206       2.497816     21.057291           0.0       4.081284      8.277083
# 207       1.648252     12.729167           0.0       4.327306      9.772917
# 208       3.464381     31.760416           0.0       5.416667     11.348958
# 209       3.461285     33.380207           0.0       7.126215     12.547916
#
#      sun_time_min  mean_humid_mean  mean_humid_max  mean_humid_min      area
# 0        0.000000        71.760002       93.000000       43.000000        千葉
# 1        0.000000        58.612904       86.000000       37.000000        千葉
# 2        0.000000        54.838711       89.000000       32.000000        千葉
# 3        0.000000        55.714287       93.000000       31.000000        千葉
# 4        0.000000        59.129032       91.000000       31.000000        千葉
# ..            ...              ...             ...             ...       ...
# 205      0.020833        72.726143       89.510414       55.208332  全国_宮城_秋田
# 206      0.001042        69.200935       88.729164       53.145832  全国_宮城_秋田
# 207      0.004167        66.868675       87.885414       51.885418  全国_宮城_秋田
# 208      0.003125        68.407593       89.468750       46.000000  全国_宮城_秋田
# 209      0.000000        67.398613       93.677086       43.541668  全国_宮城_秋田
#
# [33810 rows x 21 columns]

# %%
target
# Out:
#          year  month  mean_mean_temp  max_mean_temp  min_mean_temp  \
# 0      2004.0   11.0       14.596000          19.30           9.60
# 1      2004.0   12.0        9.641935          19.00           2.20
# 2      2005.0    1.0        6.277419          13.10           3.10
# 3      2005.0    2.0        5.960714          12.00           3.30
# 4      2005.0    3.0        8.800000          13.70           1.60
# ...       ...    ...             ...            ...            ...
# 50815  2021.0   12.0        3.674194           9.50          -2.35
# 50816  2022.0    1.0        0.517742           4.20          -2.00
# 50817  2022.0    2.0        0.883929           4.55          -1.80
# 50818  2022.0    3.0        6.453226          13.40           1.35
# 50819  2022.0    4.0       12.395000          19.80           4.85
#
#        mean_max_temp  max_max_temp  min_max_temp  mean_min_temp  max_min_temp  \
# 0          18.340000         22.20         12.40      11.228000         17.40
# 1          13.564516         24.30          3.80       6.138710         11.50
# 2          10.461290         17.20          5.20       2.522581          6.40
# 3           9.864286         15.40          5.10       2.060714          4.60
# 4          13.122581         18.40          3.60       4.596774         10.00
# ...              ...           ...           ...            ...           ...
# 50815       7.722581         14.60         -0.65       0.106452          6.75
# 50816       3.796774          8.20          0.80      -2.572581          1.65
# 50817       4.471429         10.85         -0.50      -2.244643          0.45
# 50818      11.838710         19.60          4.55       1.927419          9.55
# 50819      18.693333         26.90          8.60       7.243333         16.25
#
#        ...  mean_sum_rain  max_sum_rain  min_sum_rain  mean_sun_time  \
# 0      ...       5.840000         87.00           0.0       5.084000
# 1      ...       2.435484         26.00           0.0       5.509677
# 2      ...       3.338710         66.50           0.0       6.612903
# 3      ...       1.910714         11.50           0.0       5.225000
# 4      ...       2.612903         22.50           0.0       5.529032
# ...    ...            ...           ...           ...            ...
# 50815  ...       6.064516         35.25           0.0       3.033871
# 50816  ...       2.669355         16.75           0.0       3.366129
# 50817  ...       2.758929         17.00           0.0       3.326786
# 50818  ...       2.137097         21.25           0.0       5.272581
# 50819  ...       3.416667         30.25           0.0       6.795000
#
#        max_sun_time  min_sun_time  mean_mean_humid  max_mean_humid  \
# 0              9.50           0.0        71.760000            93.0
# 1              9.40           0.0        58.612903            86.0
# 2              9.80           0.0        54.838710            89.0
# 3              9.70           0.0        55.714286            93.0
# 4             11.30           0.0        59.129032            91.0
# ...             ...           ...              ...             ...
# 50815          8.55           0.0        82.064516            97.5
# 50816          8.35           0.0        78.548387            93.0
# 50817          8.35           0.0        77.892857            92.5
# 50818         10.65           0.0        70.790323            90.5
# 50819         12.30           0.0        68.816667            93.5
#
#        min_mean_humid   area
# 0                43.0     千葉
# 1                37.0     千葉
# 2                32.0     千葉
# 3                31.0     千葉
# 4                31.0     千葉
# ...               ...    ...
# 50815            63.5  新潟_長野
# 50816            63.5  新潟_長野
# 50817            63.0  新潟_長野
# 50818            53.0  新潟_長野
# 50819            47.0  新潟_長野
#
# [50820 rows x 21 columns]
